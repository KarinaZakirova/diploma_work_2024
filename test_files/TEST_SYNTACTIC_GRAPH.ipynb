# %% [markdown]
# ## Построение графа взаимочастотности, где узлы — (слово, POS-tag), а рёбра отображают последовательности слов в тексте. Код заимствован из эксперимента «Graph-Based Siamese Network for Authorship Verification», где на подобных графах происходило обучение нейросетки.

# %% [markdown]
# Установка зависимостей + загрузка датасета (5 фанфиков для 10 случайных авторов)

# %%
# !pip install pymorphy3
# !pip install razdel
# Out:
# Requirement already satisfied: pymorphy3 in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy3) (0.7.2)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.10/dist-packages (from pymorphy3) (2.4.417150.4580142)
# Collecting razdel
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Installing collected packages: razdel
# Successfully installed razdel-0.5.0

# %%
from google.colab import files
import networkx as nx
import os
from pymorphy3 import MorphAnalyzer
import pandas as pd
import razdel

# %%
files.upload()

# %%
# %%capture
# !unzip "/content/fanfics_for_syntactic_graphs.zip" -d "/content"

# %%
texts_dict = {'filename': [], 'text': []}

folder_path = '/content/fanfics_for_syntactic_graphs/'
for filename in os.listdir(folder_path):
  with open(folder_path + filename, 'r', encoding='utf-8') as text_file:
    text = text_file.read()
    texts_dict['filename'].append(filename.split('.')[0])
    texts_dict['text'].append(text)

# %%
df = pd.DataFrame(texts_dict)
df
# Out:
#         filename                                               text
# 0    15855_87465  РЕКЛАМА\n- Говорю тебе, здесь, что-то не так. ...
# 1   15855_109173  Пусть горят мои стихи огнем!\nЧтоб никто не см...
# 2   58628_154229  РЕКЛАМА\n— Зой, зая… А, может, не надо?..\n— К...
# 3    23313_83926  -----\nЭпиграф: Постель – не повод для знакомс...
# 4    18704_55325  Толя сидела на крыше и вздыхала. Ночь. Звезды....
# 5     94_5435092  А ночь выдалась прохладной. Горная, звёздная, ...
# 6    15650_87850  - Да пошли вы, – резко поднимаюсь из-за парты ...
# 7    25628_64766  — Главное – не разбей этого кота, – предупрежд...
# 8    21482_55214  Холодный вечер. Еще один холодный вечер этой ч...
# 9    23313_80473  ------\nЭпиграф:\nКуда пойти, куда податься?\n...
# 10  25628_188459  Хилар сидит на полу у погасшего камина, опирая...
# 11    7286_18892  Она поднимает голову; рекламный плакат, такой ...
# 12  58628_153505  А из-под одеяла вылезать так не хочется… И под...
# 13          4_58  Доки. Контейнеры. Пробитые бочки горючего. Кро...
# 14   18704_51529  РЕКЛАМА\n•\nGETINTENT\nВы обознались! Я совсем...
# 15   18704_48857  Поляна. Вечер. Каллены, а именно Белла, Эдвард...
# 16    7286_19058  — Давай уйдем на заре…\nКогда я нахожусь среди...
# 17         4_184  — Я люблю тебя, Джесс! — кричит Памела на ухо ...
# 18    7286_19054  Сколько себя помню, ба всегда была такая – стр...
# 19          4_89  Так забавно: на земле я к ней ничего не чувств...
# 20  15650_135653  Замочная скважина издала протяжный звук, опове...
# 21   25628_90397  Если честно, мне не хватало Максимилиана. Тепе...
# 22  58628_151089        Контроль давно потерян.\n      Хотя, а б...
# 23  58628_150436  Самолёт вновь уносил его прочь…\nОблака медлен...
# 24           4_5  Истоки гомофобии\nДавным-давно, в одной далеко...
# 25  58628_155675  — Я не буду этого делать!\n— Как будто бы, я т...
# 26    7286_19226  — А у нас много общего.\nЗанзас криво усмехнул...
# 27  15650_105796  Лес, как красиво прогуливаться по нему, особен...
# 28    7286_19187  — Куда мы идем?\n— Тише. Тут страшные земли.\n...
# 29  25628_203597  - Трезвый Дункан? Удивительнейшее зрелище… - С...
# 30   23313_92708  -----\nЭпиграф: Катиться по наклонной плоскост...
# 31   23313_71268  — Значит, ты и есть лучший киллер по имени Реб...
# 32          4_45  Одна — ангел, другая — демон. Казалось бы, что...
# 33   94_10593570  - Ты же взрослый человек.\n- Угу.\n- Головой б...
# 34   15855_83411  Я смеюсь. Снова и снова. Будто это и впрямь см...
# 35   21482_55217  Грохот, оглушительный грохот. Возможно, когда ...
# 36   18704_49301  Вы, наверное, не помните меня. Когда-то я уже ...
# 37  25628_192668  - Мой Император, вы звали меня? - Ян вопросите...
# 38   15855_90181  Чернокнижник, стоявший посреди огромной комнат...
# 39   21482_55206  Сегодня я расскажу Вам историю. Маленькую исто...
# 40    94_2767233        Антипка бежал вприпрыжку по вьющейся зме...
# 41   21482_55221  Джейми занят делом. Важным делом.\nВы только п...
# 42   15855_92653  Что Я думаю насчет того что произошло в Эмбере...
# 43  15650_115231  - Прощай, - мой тихий голос разрывает эти мину...
# 44   18704_48856  РЕКЛАМА\n•\nOTM\nСтоят Сийт с Морозом рядом с ...
# 45    94_1841576  Смуглые пальцы ловко переплетали полосы липово...
# 46   23313_79357  -----\nЭпиграф: Я скажу тебе такое «спасибо», ...
# 47    94_2766759        У змей немигающие глаза, в глубине котор...
# 48   21482_55207  Дитрих не уверен, что за причина заставляет ег...
# 49  15650_135348  Молчание угнетает, не дает возможности расслаб...

# %% [markdown]
# #1. PREPROCESSING WITH PYMORPHY

# %%
def tokenize(text):
  return [_.text for _ in list(razdel.tokenize(text))]

# %%
def get_pos(parsed_token):
  extra_tags = ('LATN', 'PNCT', 'NUMB', 'intg', 'real', 'ROMN', 'UNKN')
  if parsed_token.tag.POS is not None:
    return parsed_token.tag.POS
  for tag in extra_tags:
    if tag in parsed_token.tag:
      return tag

# %%
def preprocess(text):
  has_ad = False
  tokenized_text = tokenize(text)
  morph = MorphAnalyzer()
  preprocessed_text = []
  if tokenized_text[1] == "•":
    tokenized_text = tokenized_text[3:]
  elif tokenized_text[0] == "РЕКЛАМА":
    tokenized_text = tokenized_text[1:]
  for i, token in enumerate(tokenized_text):
    parsed_token = morph.parse(token)[0]
    preprocessed_text.append((parsed_token.normal_form, get_pos(parsed_token)))
  return preprocessed_text

# %%
df['preprocessed_text'] = df['text'].apply(preprocess)
df
# Out:
#         filename                                               text  \
# 0    15855_87465  РЕКЛАМА\n- Говорю тебе, здесь, что-то не так. ...
# 1   15855_109173  Пусть горят мои стихи огнем!\nЧтоб никто не см...
# 2   58628_154229  РЕКЛАМА\n— Зой, зая… А, может, не надо?..\n— К...
# 3    23313_83926  -----\nЭпиграф: Постель – не повод для знакомс...
# 4    18704_55325  Толя сидела на крыше и вздыхала. Ночь. Звезды....
# 5     94_5435092  А ночь выдалась прохладной. Горная, звёздная, ...
# 6    15650_87850  - Да пошли вы, – резко поднимаюсь из-за парты ...
# 7    25628_64766  — Главное – не разбей этого кота, – предупрежд...
# 8    21482_55214  Холодный вечер. Еще один холодный вечер этой ч...
# 9    23313_80473  ------\nЭпиграф:\nКуда пойти, куда податься?\n...
# 10  25628_188459  Хилар сидит на полу у погасшего камина, опирая...
# 11    7286_18892  Она поднимает голову; рекламный плакат, такой ...
# 12  58628_153505  А из-под одеяла вылезать так не хочется… И под...
# 13          4_58  Доки. Контейнеры. Пробитые бочки горючего. Кро...
# 14   18704_51529  РЕКЛАМА\n•\nGETINTENT\nВы обознались! Я совсем...
# 15   18704_48857  Поляна. Вечер. Каллены, а именно Белла, Эдвард...
# 16    7286_19058  — Давай уйдем на заре…\nКогда я нахожусь среди...
# 17         4_184  — Я люблю тебя, Джесс! — кричит Памела на ухо ...
# 18    7286_19054  Сколько себя помню, ба всегда была такая – стр...
# 19          4_89  Так забавно: на земле я к ней ничего не чувств...
# 20  15650_135653  Замочная скважина издала протяжный звук, опове...
# 21   25628_90397  Если честно, мне не хватало Максимилиана. Тепе...
# 22  58628_151089        Контроль давно потерян.\n      Хотя, а б...
# 23  58628_150436  Самолёт вновь уносил его прочь…\nОблака медлен...
# 24           4_5  Истоки гомофобии\nДавным-давно, в одной далеко...
# 25  58628_155675  — Я не буду этого делать!\n— Как будто бы, я т...
# 26    7286_19226  — А у нас много общего.\nЗанзас криво усмехнул...
# 27  15650_105796  Лес, как красиво прогуливаться по нему, особен...
# 28    7286_19187  — Куда мы идем?\n— Тише. Тут страшные земли.\n...
# 29  25628_203597  - Трезвый Дункан? Удивительнейшее зрелище… - С...
# 30   23313_92708  -----\nЭпиграф: Катиться по наклонной плоскост...
# 31   23313_71268  — Значит, ты и есть лучший киллер по имени Реб...
# 32          4_45  Одна — ангел, другая — демон. Казалось бы, что...
# 33   94_10593570  - Ты же взрослый человек.\n- Угу.\n- Головой б...
# 34   15855_83411  Я смеюсь. Снова и снова. Будто это и впрямь см...
# 35   21482_55217  Грохот, оглушительный грохот. Возможно, когда ...
# 36   18704_49301  Вы, наверное, не помните меня. Когда-то я уже ...
# 37  25628_192668  - Мой Император, вы звали меня? - Ян вопросите...
# 38   15855_90181  Чернокнижник, стоявший посреди огромной комнат...
# 39   21482_55206  Сегодня я расскажу Вам историю. Маленькую исто...
# 40    94_2767233        Антипка бежал вприпрыжку по вьющейся зме...
# 41   21482_55221  Джейми занят делом. Важным делом.\nВы только п...
# 42   15855_92653  Что Я думаю насчет того что произошло в Эмбере...
# 43  15650_115231  - Прощай, - мой тихий голос разрывает эти мину...
# 44   18704_48856  РЕКЛАМА\n•\nOTM\nСтоят Сийт с Морозом рядом с ...
# 45    94_1841576  Смуглые пальцы ловко переплетали полосы липово...
# 46   23313_79357  -----\nЭпиграф: Я скажу тебе такое «спасибо», ...
# 47    94_2766759        У змей немигающие глаза, в глубине котор...
# 48   21482_55207  Дитрих не уверен, что за причина заставляет ег...
# 49  15650_135348  Молчание угнетает, не дает возможности расслаб...
#
#                                     preprocessed_text
# 0   [(-, PNCT), (говорить, VERB), (ты, NPRO), (,, ...
# 1   [(пусть, PRCL), (гореть, VERB), (мой, ADJF), (...
# 2   [(—, PNCT), (зоя, NOUN), (,, PNCT), (зая, UNKN...
# 3   [(-----, PNCT), (эпиграф, NOUN), (:, PNCT), (п...
# 4   [(толя, NOUN), (сидеть, VERB), (на, PREP), (кр...
# 5   [(а, CONJ), (ночь, NOUN), (выдаться, VERB), (п...
# 6   [(-, PNCT), (да, PRCL), (послать, VERB), (вы, ...
# 7   [(—, PNCT), (главное, NOUN), (–, PNCT), (не, P...
# 8   [(холодный, ADJF), (вечер, NOUN), (., PNCT), (...
# 9   [(------, PNCT), (эпиграф, NOUN), (:, PNCT), (...
# 10  [(хилара, NOUN), (сидеть, VERB), (на, PREP), (...
# 11  [(она, NPRO), (поднимать, VERB), (голова, NOUN...
# 12  [(а, CONJ), (из-под, PREP), (одеяло, NOUN), (в...
# 13  [(док, NOUN), (., PNCT), (контейнер, NOUN), (....
# 14  [(вы, NPRO), (обознаться, VERB), (!, PNCT), (я...
# 15  [(поляна, NOUN), (., PNCT), (вечер, NOUN), (.,...
# 16  [(—, PNCT), (давать, VERB), (уйти, VERB), (на,...
# 17  [(—, PNCT), (я, NPRO), (любить, VERB), (ты, NP...
# 18  [(сколько, ADVB), (себя, NPRO), (помнить, VERB...
# 19  [(так, CONJ), (забавно, ADVB), (:, PNCT), (на,...
# 20  [(замочный, ADJF), (скважина, NOUN), (издать, ...
# 21  [(если, CONJ), (честно, ADVB), (,, PNCT), (я, ...
# 22  [(контроль, NOUN), (давно, ADVB), (потерянный,...
# 23  [(самолёт, NOUN), (вновь, ADVB), (уносить, VER...
# 24  [(исток, NOUN), (гомофобия, NOUN), (давным-дав...
# 25  [(—, PNCT), (я, NPRO), (не, PRCL), (быть, VERB...
# 26  [(—, PNCT), (а, CONJ), (у, PREP), (мы, NPRO), ...
# 27  [(лес, NOUN), (,, PNCT), (как, CONJ), (красиво...
# 28  [(—, PNCT), (куда, CONJ), (мы, NPRO), (идти, V...
# 29  [(-, PNCT), (трезвый, ADJF), (дункан, NOUN), (...
# 30  [(-----, PNCT), (эпиграф, NOUN), (:, PNCT), (к...
# 31  [(—, PNCT), (значит, CONJ), (,, PNCT), (ты, NP...
# 32  [(один, ADJF), (—, PNCT), (ангел, NOUN), (,, P...
# 33  [(-, PNCT), (ты, NPRO), (же, PRCL), (взрослый,...
# 34  [(я, NPRO), (смеяться, VERB), (., PNCT), (снов...
# 35  [(грохот, NOUN), (,, PNCT), (оглушительный, AD...
# 36  [(вы, NPRO), (,, PNCT), (наверное, CONJ), (,, ...
# 37  [(-, PNCT), (мой, ADJF), (император, NOUN), (,...
# 38  [(чернокнижник, NOUN), (,, PNCT), (стоять, PRT...
# 39  [(сегодня, ADVB), (я, NPRO), (рассказать, VERB...
# 40  [(антипка, UNKN), (бежать, VERB), (вприпрыжку,...
# 41  [(дженять, VERB), (занятый, ADJS), (дело, NOUN...
# 42  [(что, CONJ), (я, NPRO), (думать, VERB), (насч...
# 43  [(-, PNCT), (прощать, VERB), (,, PNCT), (-, PN...
# 44  [(стоять, VERB), (сийт, NOUN), (с, PREP), (мор...
# 45  [(смуглый, ADJF), (палец, NOUN), (ловко, ADVB)...
# 46  [(-----, PNCT), (эпиграф, NOUN), (:, PNCT), (я...
# 47  [(у, PREP), (змея, NOUN), (немигающий, ADJF), ...
# 48  [(дитрих, NOUN), (не, PRCL), (уверенный, ADJS)...
# 49  [(молчание, NOUN), (угнетать, VERB), (,, PNCT)...

# %% [markdown]
# # 2. BUILDING GRAPHS

# %%
# !pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.2.0)

# %%
import networkx as nx
import time
from itertools import chain
from collections import deque, Counter
from sys import getsizeof, stderr
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from torch_geometric import utils
import torch
from tqdm import tqdm
from joblib import Parallel, delayed
import sys
from torch_geometric.utils import convert, softmax

# %% [markdown]
# Список POS-tags (тегов частей речи) для построения графов

# %%
_classes = ['NOUN', 'ADJF', 'ADJS', 'COMP', 'VERB', 'INFN', 'PRTF', 'PRTS', 'GRND', 'NUMR', 'ADVB', 'NPRO', 'PRED', 'PREP', 'CONJ', 'PRCL', 'INTJ', 'LATN', 'PNCT', 'NUMB', 'intg', 'real', 'ROMN', 'UNKN']

# %% [markdown]
# Далее идёт код построения и визуализации графов, заимствованный из работы [«Graph-Based Siamese Network for authorship Verification»](https://www.researchgate.net/publication/357906614_Graph-Based_Siamese_Network_for_Authorship_Verification)

# %% [markdown]
# Класс ToGraph, который создаёт графы из текста (логика создания графа); Класс ToCoocurrence, который создаёт графы из предобработанного текста, подающегося в виде пар (слово, POS-tag)

# %%
class ToGraph:
    """Parent class to generate networkx graph from parsed text"""

    def __init__(self, graph_type='Graph'):
        self.graph_type = graph_type
        if graph_type == 'MultiDiGraph':
            self.G = nx.MultiDiGraph()
        elif graph_type == 'MultiGraph':
            self.G = nx.MultiGraph()
        elif graph_type == 'DiGraph':
            self.G = nx.DiGraph()
        elif graph_type == 'Graph':
            self.G = nx.Graph()
        else:
            print('invalid graph type')
            exit()

    def node_label(self, word):
        """Set the name of each node"""

        return word

    def grown_graph(self, text):
        """Add nodes and edges from parsed text"""

        pass

    def final_tune(self, remove_loops=True):
        """Optional final operation in graph"""

        if remove_loops is True:
            self.G.remove_edges_from(nx.selfloop_edges(self.G))

    def define_node_mask(self, measure=nx.closeness_centrality):
        """Used in unmasking"""

        # Get measure for all nodes
        nodes_measure = measure(self.G)
        return nodes_measure

    def show_graph(self, graph_id=None, dest_folder='graphs'):
        """Method for graphing multigraphs with graphviz.
        Saves the image as a file"""

        name = self.graph_type + '_' + str(graph_id) + '.png'
        if not os.path.exists(dest_folder):
            os.makedirs(dest_folder)

        path = os.path.join(dest_folder,  name)
        nx.draw_networkx(self.G)
        plt.savefig(path)


class ToCoocurrence(ToGraph):
    """Coocurrence graph from parsed text"""

    def __init__(self,
                 reduce_classes=[],
                 graph_type='Graph', weigth_labels=True):
        super().__init__(graph_type)
        self.weigth_labels = weigth_labels
        self.reduce_classes = reduce_classes

    def node_label(self, token):
        if token[1] not in self.reduce_classes:
            return token
        else:
            return (('$' + str(token[1])), token[1])

    def define_edges(self, text_tag):
        """Get list of edges. Used to test formats"""

        # Coocurrence edges loop
        edges_list = []
        node_pre = self.node_label(text_tag[0])
        for token in text_tag[1:]:
            node_act = self.node_label(token)
            edges_list.append((node_pre, node_act))
            node_pre = node_act

        total = len(edges_list)
        edges = [(node_pre, node_act, (c / total))
                 for (node_pre, node_act), c in Counter(edges_list).items()]
        return edges

    def grown_from_edges(self, edges):
        """Add edges to graph. Used to test formats"""

        self.G.add_weighted_edges_from(edges)
        # self.final_tune()

    def grown_graph(self, text_tag):
        edges = self.define_edges(text_tag)
        self.grown_from_edges(edges)

    def to_sparse_raw(self):
        """Transform to scipy sparse array and node list"""

        node_names = list(self.G.nodes())
        sparse = nx.convert_matrix.to_scipy_sparse_array(self.G)
        return sparse, node_names

    def to_sparse(self, return_node_words=False):
        """Transform to scipy sparse matrix. Used to test formats"""
        node_pos = [node[1] for node in self.G.nodes()]
        sparse = nx.convert_matrix.to_scipy_sparse_array(self.G)
        if return_node_words:
            node_words = [node for node in self.G.nodes()]
            return sparse, node_pos, node_words

        else:
            return sparse, node_pos

    def to_sparse_encoded(self):
        """Transform to scipy sparse matrix with the POS categories as attributes in sparse hue as well.
        Used to test formats"""

        sparse, node_pos = self.to_sparse()
        node_attr = encode_pos(node_pos)
        return sparse, node_attr

    def to_data(self, pos_encoder='default'):
        """Transform to pytorch tensor as it would be used in torch geometric.
        Used to test formats"""

        nx_graph = self.G
        # verify graph type
        assert type(nx_graph).__name__ in ['Graph', 'DiGraph']

        # Define graph, edges weight to edge_attr
        weight = 'weight'
        data = utils.from_networkx(nx_graph)
        data_dir = dir(data)
        if weight in data_dir:
            data['edge_attr'] = data[weight]
            delattr(data, weight)

        x_names = list(nx_graph.nodes)
        data['x_names'] = x_names

        # Convert pos in node feature and node class
        x_pos = [n[1] for n in x_names]
        if pos_encoder == 'default':
            pos_encoder = OneHotEncoder(categories=[_classes])

        x_pos = np.array(x_pos).reshape(-1, 1)
        x_sparse = pos_encoder.fit_transform(x_pos)
        x = torch.from_numpy(x_sparse.toarray())
        data['x'] = x
        return data

# %% [markdown]
# Создаём графы из текстов датасета

# %%
def text_parsed_to_graph_sparse_raw(parsed, graph_type='DiGraph', graph_id=0):
  # передавать пустой список в ToCoocurrence для сохранения информации о словах
    coocurrence = ToCoocurrence(_classes, graph_type)
    coocurrence.grown_graph(parsed)
    print('----------ToGraph.show_attributes method')
    print('graph_type: ', coocurrence.graph_type)
    print('Nodes:', nx.number_of_nodes(coocurrence.G))
    print('Edges:', nx.number_of_edges(coocurrence.G))
    print('loops:', nx.number_of_selfloops(coocurrence.G))
    coocurrence.show_graph(graph_id)
    return coocurrence

# %% [markdown]
# После применения функции ко всем текстам рисуется общий граф для **всех** текстов (все графы выводятся на одном полотне)

# %%
df['graph'] = df['preprocessed_text'].apply(text_parsed_to_graph_sparse_raw)
df.head()
# Out:
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 148
# loops: 11
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 165
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 126
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 153
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 155
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 108
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 21
# Edges: 165
# loops: 10
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 155
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 148
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 152
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 17
# Edges: 150
# loops: 10
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 130
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 125
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 159
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 20
# Edges: 150
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 161
# loops: 10
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 17
# Edges: 112
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 157
# loops: 10
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 17
# Edges: 101
# loops: 7
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 148
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 150
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 145
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 17
# Edges: 122
# loops: 7
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 16
# Edges: 122
# loops: 7
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 22
# Edges: 145
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 154
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 121
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 16
# Edges: 135
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 126
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 142
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 136
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 152
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 20
# Edges: 172
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 107
# loops: 6
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 126
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 142
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 20
# Edges: 151
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 17
# Edges: 149
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 140
# loops: 12
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 134
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 152
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 17
# Edges: 131
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 145
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 151
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 20
# Edges: 144
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 129
# loops: 7
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 144
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 157
# loops: 8
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 18
# Edges: 146
# loops: 9
# ----------ToGraph.show_attributes method
# graph_type:  DiGraph
# Nodes: 19
# Edges: 159
# loops: 10
#        filename                                               text  \
# 0   15855_87465  РЕКЛАМА\n- Говорю тебе, здесь, что-то не так. ...
# 1  15855_109173  Пусть горят мои стихи огнем!\nЧтоб никто не см...
# 2  58628_154229  РЕКЛАМА\n— Зой, зая… А, может, не надо?..\n— К...
# 3   23313_83926  -----\nЭпиграф: Постель – не повод для знакомс...
# 4   18704_55325  Толя сидела на крыше и вздыхала. Ночь. Звезды....
#
#                                    preprocessed_text  \
# 0  [(-, PNCT), (говорить, VERB), (ты, NPRO), (,, ...
# 1  [(пусть, PRCL), (гореть, VERB), (мой, ADJF), (...
# 2  [(—, PNCT), (зоя, NOUN), (,, PNCT), (зая, UNKN...
# 3  [(-----, PNCT), (эпиграф, NOUN), (:, PNCT), (п...
# 4  [(толя, NOUN), (сидеть, VERB), (на, PREP), (кр...
#
#                                                graph
# 0  <__main__.ToCoocurrence object at 0x7aae8b07b100>
# 1  <__main__.ToCoocurrence object at 0x7aae8b078340>
# 2  <__main__.ToCoocurrence object at 0x7aae8b07a1a0>
# 3  <__main__.ToCoocurrence object at 0x7aae8e183e20>
# 4  <__main__.ToCoocurrence object at 0x7aae8b949420>

# %% [markdown]
# Далее строю графы для текстов отдельно взятого автора. Узлы — (POS-tag, POS-tag), это можно изменить на (слово, POS-tag) путём замены строчки кода выше. Сейчас оставила так, поскольку построение графа с подобным узлом занимает много времени (где-то больше получаса для 50 текстов + полотно графа менее читаемо, по сравнению с тем, что ниже)

# %%
import matplotlib.pyplot as plt

for i, graph in enumerate(df.loc[df["filename"].str.contains("15855")]["graph"]):
  plt.figure(i)
  nx.draw_networkx(graph.G)

  #nx.draw_networkx(df["graph"][0].G)
